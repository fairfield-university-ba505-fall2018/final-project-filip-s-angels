# %% [markdown]
# # Research Questions
# 1. Which attributes are most associated with **poisonous** mushrooms?
# 2. Which attributes are most associated with **edible** mushroooms?
# 3. Are poisonous mushrooms found most often in abundance, clusters, etc?
# 4. What cap color is most associated with poisonous mushrooms?
# 5. Other comparisons of posisonous mushrooms vs. edible mushrooms
# 6. Where are these mushrooms most often found? (Question that may require some advanced techniques)

# %% [markdown]
# # **Mushroom Classification – Poisonous or not.**
# * A **mushroom**, or *toadstool*, is the *fleshy, spore-bearing* fruiting body of a fungus, typically produced above ground on soil or on its food source.
# * A *“Mushroom”* also describes a variety of other gilled fungi, *with or without* stems.
#
# ## Data Source
# * For our final project we chose a classification dataset. The data that we found is on the *classification of mushrooms* and what *distinctive features* help us determine whether they are poisonous or not. We gathered this data from **Kaggle**.

# %% [markdown]
# ## Mushroom Features
#
# * We began exploring the dataset by performing extra research pertaining to mushroom anatomy, interpreting the variables, and the meaning behind them.
#
# ### Glossary
#    1. **Cap (*Pileus*):**
#         * the *expanded*, upper part of the mushroom; whose surface is the *pileus*
#    2. **Cup (*Volva*):**
#     * a *cup-shaped* structure at the base of the mushroom. The basal cup is the remnant of the button (the rounded, undeveloped mushroom before the fruiting body appears). **Not all** mushrooms have a *cup*.
#    3. **Gills (*Lamellae*):**
#     * a series of *radially arranged* (from the center) *flat surfaces* located on the *underside* of the cap. Spores are *made* in the gills.
#    4. **Mycelial threads:**
#     * *root-like* filaments that *anchor* the mushroom in the soli.
#    5. **Ring (*Annulus*):**
#     * a *skirt-like ring* of tissue circling the stem of *mature* mushrooms. The ring is the remnant of the veil (the veil is the tissue that connects the stem and the cap before the gills are exposed and the fruiting body develops). **Not all** mushrooms have a *ring*.
#    6. **Scale:**
#     * rough *patches of tissue* on the surface of the cap (scales are remnants of the veil).
#    7. **Stalk (or *Stem*, or *Stape*):**
#     * the *main support* of the mushroom; it is topped by the cap. **Not all** mushrooms have a *stalk* (*stem*).

# %% [markdown]
# ![alt text](https://github.com/fairfield-university-ba505-fall2018/final-project-filip-s-angels/raw/master/Structure%2Bof%2Ba%2Bcommon%2Bmushroom.jpg "Mushroom_Structure")

# %% [markdown]
# ![alt text](https://github.com/fairfield-university-ba505-fall2018/final-project-filip-s-angels/raw/master/mushroom_cap_morphology2.png "Mushroom_Cap")

# %% [markdown]
# ### Data Attribute Information
# | Column Name  | Contents |
# | ------------- | ------------- |
# | **classes**   | edible=e, poisonous=p  |
# | **cap-shape**   | bell=b, conical=c, convex=x, flat=f, knobbed=k, sunken=s  |
# | **cap-surface**   | fibrous=f, grooves=g, scaly=y, smooth=s |
# | **cap-color**   | brown=n, buff=b, cinnamon=c, gray=g, green=r, pink=p, purple=u, red=e, white=w, yellow=y  |
# | **bruises**    | bruises=t, no=f  |
# | **odor**   | almond=a, anise=l, creosote=c, fishy=y, foul=f, musty=m, none=n, pungent=p, spicy=s  |
# | **gill-attachment** | attached=a, descending=d, free=f, notched=n  |
# | **gill-spacing** | close=c, crowded=w, distant=d  |
# | **gill-size**  | broad=b, narrow=n  |
# | **gill-color** | black=k, brown=n, buff=b, chocolate=h, gray=g, green=r, orange=o, pink=p, purple=u, red=e, white=w, yellow=y  |
# | **stalk-shape**  | enlarging=e, tapering=t |
# | **stalk-root** | attached=a, descending=d, free=f, notched=n  |
# | **stalk-surface-above-ring** | fibrous=f, scaly=y, silky=k, smooth=s  |
# | **stalk-surface-below-ring** | fibrous=f, scaly=y, silky=k, smooth=s  |
# | **stalk-color-above-ring** | brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y  |
# | **stalk-color-below-ring** | brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y  |
# | **veil-type**  | partial=p, universal=u  |
# | **veil-color** | brown=n, orange=o, white=w, yellow=y  |
# | **ring-number** | none=n, one=o, two=t  |
# | **ring-type** | cobwebby=c, evanescent=e, flaring=f, large=l, none=n, pendant=p, sheathing=s, zone=z  |
# | **spore-print-color** | black=k, brown=n, buff=b, chocolate=h, green=r, orange=o, purple=u, white=w, yellow=y  |
# | **population** | abundant=a, clustered=c, numerous=n, scattered=s, several=v, solitary=y  |
# |  **habitat**| grasses=g, leaves=l, meadows=m, paths=p, urban=u, waste=w, woods=d |

# %%
#Importing NumPy, Pandas and Matplotlib.pyplot 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Importing csv as 'mushroom', this dataset will be recoded to numbers for regression and correlation purposes.
mushroom=pd.read_csv('mushroom_classification.csv',header=0)

# %%
#Recoding variables
class_dict={'e':0,'p':1}
mushroom['class']=mushroom['class'].map(class_dict)

# %%
#Recoding variables
cshape_dict={'b':0,'c':1,'f':2, 'k':3, 's':4, 'x':5}
mushroom['cap-shape']=mushroom['cap-shape'].map(cshape_dict)

# %%
#Recoding variables
csurface_dict={'f':0, 'g':1, 'y':2, 's':3}
mushroom['cap-surface']=mushroom['cap-surface'].map(csurface_dict)

# %%
#Recoding variables
ccolor_dict={'n':0,'b':1,'c':2,'g':3, 'r':4,'p':5,'u':6,'e':7,'w':8,'y':9}
mushroom['cap-color']=mushroom['cap-color'].map(ccolor_dict)

# %%
#Recoding variables
bruises_dict={'t':0, 'f':1}
mushroom['bruises']=mushroom['bruises'].map(bruises_dict)

# %%
#Recoding variables
odor_dict={'a':0,'l':1,'c':2,'y':3,'f':4,'m':5,'n':6,'p':7,'s':8}
mushroom['odor']=mushroom['odor'].map(odor_dict)

# %%
#Recoding variables
gilla_dict={'a':0,'d':1,'f':2,'n':3}
mushroom['gill-attachment']=mushroom['gill-attachment'].map(gilla_dict)

# %%
#Recoding variables
gillsp_dict={'c':0,'w':1,'d':2}
mushroom['gill-spacing']=mushroom['gill-spacing'].map(gillsp_dict)

# %%
#Recoding variables
gillsi_dict={'b':0,'n':1}
mushroom['gill-size']=mushroom['gill-size'].map(gillsi_dict)

# %%
#Recoding variables
gillc_dict={'n':0,'b':1,'c':2,'g':3, 'r':4,'p':5,'u':6,'e':7,'w':8,'y':9,'k':10,'h':11,'o':12}
mushroom['gill-color']=mushroom['gill-color'].map(gillc_dict)

# %%
#Recoding variables
stalkshape_dict={'e':0,'t':1}
mushroom['stalk-shape']=mushroom['stalk-shape'].map(stalkshape_dict)

# %%
#Recoding variables
stalkroot_dict={'?':0,'b':1,'c':2,'u':3,'e':4,'z':5,'r':6}
mushroom['stalk-root']=mushroom['stalk-root'].map(stalkroot_dict)

# %%
#Recoding variables
stalksring_dict={'f':0,'y':1,'k':2,'s':3}
mushroom['stalk-surface-above-ring']=mushroom['stalk-surface-above-ring'].map(stalksring_dict)
mushroom['stalk-surface-below-ring']=mushroom['stalk-surface-below-ring'].map(stalksring_dict)

# %%
#Recoding variables
stalkscolor_dict={'n':0,'b':1,'c':2,'g':3,'o':4,'p':5,'e':6,'w':7,'y':8}
mushroom['stalk-color-above-ring']=mushroom['stalk-color-above-ring'].map(stalkscolor_dict)
mushroom['stalk-color-below-ring']=mushroom['stalk-color-below-ring'].map(stalkscolor_dict)

# %%
#Recoding variables
veilc_dict={'n':0,'o':1,'w':2,'y':3}
mushroom['veil-color']=mushroom['veil-color'].map(veilc_dict)

# %%
#Recoding variables
ringnum_dict={'n':0,'o':1,'t':2}
mushroom['ring-number']=mushroom['ring-number'].map(ringnum_dict)

# %%
#Recoding variables
ringtyp_dict={'c':0,'e':1,'f':2,'l':3,'n':4,'p':5,'s':6,'z':7}
mushroom['ring-type']=mushroom['ring-type'].map(ringtyp_dict)

# %%
#Recoding variables
sporepc_dict={'k':0,'n':1,'b':2,'h':3,'r':4,'o':5,'u':6,'w':7,'y':8}
mushroom['spore-print-color']=mushroom['spore-print-color'].map(sporepc_dict)

# %%
#Recoding variables
pop_dict={'a':0,'c':1,'n':2,'s':3,'v':4,'y':5}
mushroom['population']=mushroom['population'].map(pop_dict)

# %%
#Recoding variables
hab_dict={'g':0,'l':1,'m':2,'p':3,'u':4,'w':5,'d':6}
mushroom['habitat']=mushroom['habitat'].map(hab_dict)

# %%
#Creating bar chart to show edible vs. poisonous mushrooms from dataset
mushroom['class'].value_counts().plot(kind='bar')
plt.title('Edible versus Poisonous Mushrooms')
plt.ylabel('Number of Mushrooms')
plt.xticks(np.arange(2), ('edible', 'poison'), rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7f13e33e5438>,
#   <matplotlib.axis.XTick at 0x7f13e33d9d30>],
#  <a list of 2 Text xticklabel objects>)

# %%
#Creating bar chart to visualize different cap shape types
mushroom['cap-shape'].value_counts().plot(kind='bar')
plt.title('Cap Shape Type')
plt.ylabel('Number of Mushrooms')
plt.xticks(np.arange(6), ('convex','flat','knobbed','bell','sunken','conical'), rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7f13e3348390>,
#   <matplotlib.axis.XTick at 0x7f13e333dc88>,
#   <matplotlib.axis.XTick at 0x7f13e335bef0>,
#   <matplotlib.axis.XTick at 0x7f13e3370828>,
#   <matplotlib.axis.XTick at 0x7f13e3370cc0>,
#   <matplotlib.axis.XTick at 0x7f13e32fa1d0>],
#  <a list of 6 Text xticklabel objects>)

# %%
#Creating bar chart to visualize various mushroom habitats 
mushroom['habitat'].value_counts().plot(kind='bar')
plt.title('Which habitat is most common?')
plt.ylabel('Number of Mushrooms')
plt.xlabel('Habitat')
plt.xticks(np.arange(7), ('woods','grass','paths','leaves','urban','meadows','waste'), rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7f13e332f8d0>,
#   <matplotlib.axis.XTick at 0x7f13e332f240>,
#   <matplotlib.axis.XTick at 0x7f13e32d5da0>,
#   <matplotlib.axis.XTick at 0x7f13e32e00b8>,
#   <matplotlib.axis.XTick at 0x7f13e32e0518>,
#   <matplotlib.axis.XTick at 0x7f13e32e09e8>,
#   <matplotlib.axis.XTick at 0x7f13e32e0ef0>],
#  <a list of 7 Text xticklabel objects>)

# %%
#Creating bar chart to visualize various mushroom habitats 
mushroom['population'].value_counts().plot(kind='bar')
plt.title('Which population is most common?')
plt.ylabel('Number of Mushrooms')
plt.xlabel('Population')
plt.xticks(np.arange(6), ('several','solitary','scattered','numerous','abundant','clustered'), rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7f13e3297d68>,
#   <matplotlib.axis.XTick at 0x7f13e32976a0>,
#   <matplotlib.axis.XTick at 0x7f13e35ba7b8>,
#   <matplotlib.axis.XTick at 0x7f13e35fe780>,
#   <matplotlib.axis.XTick at 0x7f13e364d0f0>,
#   <matplotlib.axis.XTick at 0x7f13e364d9b0>],
#  <a list of 6 Text xticklabel objects>)

# %%
#Creating heatmap correlation for the entire dataset using Seaborn
corr = mushroom.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
#Creating separate dataframe for just the mushrooms classified as poisonous 
poison = mushroom[mushroom['class']==1]
poison.head()
# Out:
#     class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0       1          5            3          0        0     7                2
# 3       1          5            2          8        0     7                2
# 8       1          5            2          8        0     7                2
# 13      1          5            2          8        0     7                2
# 17      1          5            3          0        0     7                2
#
#     gill-spacing  gill-size  gill-color   ...     stalk-surface-below-ring  \
# 0              0          1          10   ...                            3
# 3              0          1           0   ...                            3
# 8              0          1           5   ...                            3
# 13             0          1          10   ...                            3
# 17             0          1           0   ...                            3
#
#     stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                        7                       7          p           2
# 3                        7                       7          p           2
# 8                        7                       7          p           2
# 13                       7                       7          p           2
# 17                       7                       7          p           2
#
#     ring-number ring-type  spore-print-color  population  habitat
# 0             1         5                  0           3        4
# 3             1         5                  0           3        4
# 8             1         5                  0           4        0
# 13            1         5                  1           4        4
# 17            1         5                  0           3        0
#
# [5 rows x 23 columns]

# %%
edible= mushroom[mushroom['class']==0]
edible.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 1      0          5            3          9        0     0                2
# 2      0          0            3          8        0     1                2
# 4      0          5            3          3        1     6                2
# 5      0          5            2          9        0     0                2
# 6      0          0            3          8        0     0                2
#
#    gill-spacing  gill-size  gill-color   ...     stalk-surface-below-ring  \
# 1             0          0          10   ...                            3
# 2             0          0           0   ...                            3
# 4             1          0          10   ...                            3
# 5             0          0           0   ...                            3
# 6             0          0           3   ...                            3
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 1                       7                       7          p           2
# 2                       7                       7          p           2
# 4                       7                       7          p           2
# 5                       7                       7          p           2
# 6                       7                       7          p           2
#
#    ring-number ring-type  spore-print-color  population  habitat
# 1            1         5                  1           2        0
# 2            1         5                  1           2        2
# 4            1         1                  1           0        0
# 5            1         5                  0           2        0
# 6            1         5                  0           2        2
#
# [5 rows x 23 columns]

# %%
#Creating heatmap correlation for the mushrooms classified as edible using Seaborn
corr= edible.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, cmap='YlGnBu')

# %%
#Creating heatmap correlation for the mushrooms classified as poisonousx using Seaborn
corr2 = poison.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, cmap='Reds')

# %%
test = mushroom.groupby(['population', 'class'])['population'].count().unstack('class').fillna(0)
test.plot(kind='bar', stacked=True, color=["green","red"])
plt.legend(['edible','poison'])
plt.xticks(np.arange(6), ('several','solitary','scattered','numerous','abundant','clustered'), rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7f13e2ffd0f0>,
#   <matplotlib.axis.XTick at 0x7f13e306d470>,
#   <matplotlib.axis.XTick at 0x7f13e302ae80>,
#   <matplotlib.axis.XTick at 0x7f13e30342e8>,
#   <matplotlib.axis.XTick at 0x7f13e3034908>,
#   <matplotlib.axis.XTick at 0x7f13e3034dd8>],
#  <a list of 6 Text xticklabel objects>)

# %%
test = mushroom.groupby(['class', 'bruises'])['class'].count().unstack('bruises').fillna(0)
test.plot(kind='bar', stacked=True)
plt.legend(['bruises present', 'no bruises'])
plt.xticks(np.arange(2), ('edible', 'poison'), rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7f13e32314e0>,
#   <matplotlib.axis.XTick at 0x7f13e3213dd8>],
#  <a list of 2 Text xticklabel objects>)

# %%
test = mushroom.groupby(['class', 'gill-size'])['class'].count().unstack('gill-size').fillna(0)
test.plot(kind='bar', stacked=True)
plt.legend(['broad', 'narrow'])
plt.xticks(np.arange(2), ('edible', 'poison'), rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7f13e307c0f0>,
#   <matplotlib.axis.XTick at 0x7f13e307c908>],
#  <a list of 2 Text xticklabel objects>)

# %%
test = mushroom.groupby(['class', 'ring-type'])['class'].count().unstack('ring-type').fillna(0)
test.plot(kind='bar', stacked=True)
plt.legend(['evanescent','flaring','large','none','pendant'])
plt.xticks(np.arange(2), ('edible', 'poison'), rotation='horizontal')
#cobwebby,zone and sheathing are not present at all
# Out:
# ([<matplotlib.axis.XTick at 0x7f13e2efab38>,
#   <matplotlib.axis.XTick at 0x7f13e2efa470>],
#  <a list of 2 Text xticklabel objects>)

# %%
test = mushroom.groupby(['class', 'spore-print-color'])['class'].count().unstack('spore-print-color').fillna(0)
test.plot(kind='bar', stacked=True, color=['black','brown','beige','chocolate','green','orange','purple','grey','yellow'])
plt.xticks(np.arange(2), ('edible', 'poison'), rotation='horizontal')
plt.legend(['black','brown','buff','chocolate','green','orange','purple','white','yellow'])

# %%
#Mushrooms tend to have white-veil colors and free gill attachments. But this does not help us catergorize edible versus posion. 
test = edible.groupby(['gill-attachment', 'veil-color'])['gill-attachment'].count().unstack('veil-color').fillna(0)
test.plot(kind='bar', stacked=True)
plt.xticks(np.arange(2), ('attached', 'free'), rotation='horizontal')
plt.legend(['brown','orange','white'])

# %%
#Mushrooms tend to have white-veil colors and free gill attachments. But this does not help us catergorize edible versus posion. 
test = poison.groupby(['gill-attachment', 'veil-color'])['gill-attachment'].count().unstack('veil-color').fillna(0)
test.plot(kind='bar', stacked=True)
plt.xticks(np.arange(2), ('attached', 'free'), rotation='horizontal')
plt.legend(['white','yellow'])
