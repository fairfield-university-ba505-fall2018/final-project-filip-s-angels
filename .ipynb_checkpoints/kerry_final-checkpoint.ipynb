# %%
#Importing NumPy, Pandas and Matplotlib.pyplot 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
mushroom=pd.read_csv('mushroom_classification.csv',header=0)
mushroom.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
#Recoding all string responses to numerical data. 
class_dict={'e':0,'p':1}
mushroom['class']=mushroom['class'].map(class_dict)

# %%
cshape_dict={'b':0,'c':1,'f':2, 'k':3, 's':4, 'x':5}
mushroom['cap-shape']=mushroom['cap-shape'].map(cshape_dict)

# %%
csurface_dict={'f':0, 'g':1, 'y':2, 's':3}
mushroom['cap-surface']=mushroom['cap-surface'].map(csurface_dict)

# %%
ccolor_dict={'n':0,'b':1,'c':2,'g':3, 'r':4,'p':5,'u':6,'e':7,'w':8,'y':9}
mushroom['cap-color']=mushroom['cap-color'].map(ccolor_dict)

# %%
bruises_dict={'t':0, 'f':1}
mushroom['bruises']=mushroom['bruises'].map(bruises_dict)

# %%
odor_dict={'a':0,'l':1,'c':2,'y':3,'f':4,'m':5,'n':6,'p':7,'s':8}
mushroom['odor']=mushroom['odor'].map(odor_dict)

# %%
gilla_dict={'a':0,'d':1,'f':2,'n':3}
mushroom['gill-attachment']=mushroom['gill-attachment'].map(gilla_dict)

# %%
gillsp_dict={'c':0,'w':1,'d':2}
mushroom['gill-spacing']=mushroom['gill-spacing'].map(gillsp_dict)

# %%
gillsi_dict={'b':0,'n':1}
mushroom['gill-size']=mushroom['gill-size'].map(gillsi_dict)

# %%
gillc_dict={'n':0,'b':1,'c':2,'g':3, 'r':4,'p':5,'u':6,'e':7,'w':8,'y':9,'k':10,'h':11,'o':12}
mushroom['gill-color']=mushroom['gill-color'].map(gillc_dict)

# %%
stalkshape_dict={'e':0,'t':1}
mushroom['stalk-shape']=mushroom['stalk-shape'].map(stalkshape_dict)

# %%
stalkroot_dict={'?':0,'b':1,'c':2,'u':3,'e':4,'z':5,'r':6}
mushroom['stalk-root']=mushroom['stalk-root'].map(stalkroot_dict)

# %%
stalksring_dict={'f':0,'y':1,'k':2,'s':3}
mushroom['stalk-surface-above-ring']=mushroom['stalk-surface-above-ring'].map(stalksring_dict)
mushroom['stalk-surface-below-ring']=mushroom['stalk-surface-below-ring'].map(stalksring_dict)

# %%
stalkscolor_dict={'n':0,'b':1,'c':2,'g':3,'o':4,'p':5,'e':6,'w':7,'y':8}
mushroom['stalk-color-above-ring']=mushroom['stalk-color-above-ring'].map(stalkscolor_dict)
mushroom['stalk-color-below-ring']=mushroom['stalk-color-below-ring'].map(stalkscolor_dict)

# %%
veilt_dict={'p':0,'u':1}
mushroom['veil-type']=mushroom['veil-type'].map(veilt_dict)

# %%
veilc_dict={'n':0,'o':1,'w':2,'y':3}
mushroom['veil-color']=mushroom['veil-color'].map(veilc_dict)

# %%
ringnum_dict={'n':0,'o':1,'t':2}
mushroom['ring-number']=mushroom['ring-number'].map(ringnum_dict)

# %%
ringtyp_dict={'c':0,'e':1,'f':2,'l':3,'n':4,'p':5,'s':6,'z':7}
mushroom['ring-type']=mushroom['ring-type'].map(ringtyp_dict)

# %%
sporepc_dict={'k':0,'n':1,'b':2,'h':3,'r':4,'o':5,'u':6,'w':7,'y':8}
mushroom['spore-print-color']=mushroom['spore-print-color'].map(sporepc_dict)

# %%
pop_dict={'a':0,'c':1,'n':2,'s':3,'v':4,'y':5}
mushroom['population']=mushroom['population'].map(pop_dict)

# %%
hab_dict={'g':0,'l':1,'m':2,'p':3,'u':4,'w':5,'d':6}
mushroom['habitat']=mushroom['habitat'].map(hab_dict)

# %%
mushroom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# class                       8124 non-null int64
# cap-shape                   8124 non-null int64
# cap-surface                 8124 non-null int64
# cap-color                   8124 non-null int64
# bruises                     8124 non-null int64
# odor                        8124 non-null int64
# gill-attachment             8124 non-null int64
# gill-spacing                8124 non-null int64
# gill-size                   8124 non-null int64
# gill-color                  8124 non-null int64
# stalk-shape                 8124 non-null int64
# stalk-root                  8124 non-null int64
# stalk-surface-above-ring    8124 non-null int64
# stalk-surface-below-ring    8124 non-null int64
# stalk-color-above-ring      8124 non-null int64
# stalk-color-below-ring      8124 non-null int64
# veil-type                   8124 non-null int64
# veil-color                  8124 non-null int64
# ring-number                 8124 non-null int64
# ring-type                   8124 non-null int64
# spore-print-color           8124 non-null int64
# population                  8124 non-null int64
# habitat                     8124 non-null int64
# dtypes: int64(23)
# memory usage: 1.4 MB

# %%
mushroom['class'].value_counts().plot(kind='bar')

# %%
mushroom['cap-shape'].value_counts().plot(kind='bar')

# %%
capsurfplt = mushroom['cap-surface'].value_counts().plot(kind='bar')

# %%
poison = mushroom[mushroom['class']==1]
poison.head()
# Out:
#     class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0       1          5            3          0        0     7                2
# 3       1          5            2          8        0     7                2
# 8       1          5            2          8        0     7                2
# 13      1          5            2          8        0     7                2
# 17      1          5            3          0        0     7                2
#
#     gill-spacing  gill-size  gill-color   ...     stalk-surface-below-ring  \
# 0              0          1          10   ...                            3
# 3              0          1           0   ...                            3
# 8              0          1           5   ...                            3
# 13             0          1          10   ...                            3
# 17             0          1           0   ...                            3
#
#     stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                        7                       7          0           2
# 3                        7                       7          0           2
# 8                        7                       7          0           2
# 13                       7                       7          0           2
# 17                       7                       7          0           2
#
#     ring-number  ring-type  spore-print-color  population  habitat
# 0             1          5                  0           3        4
# 3             1          5                  0           3        4
# 8             1          5                  0           4        0
# 13            1          5                  1           4        4
# 17            1          5                  0           3        0
#
# [5 rows x 23 columns]

# %%
edible = mushroom[mushroom['class']==0]
edible.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 1      0          5            3          9        0     0                2
# 2      0          0            3          8        0     1                2
# 4      0          5            3          3        1     6                2
# 5      0          5            2          9        0     0                2
# 6      0          0            3          8        0     0                2
#
#    gill-spacing  gill-size  gill-color   ...     stalk-surface-below-ring  \
# 1             0          0          10   ...                            3
# 2             0          0           0   ...                            3
# 4             1          0          10   ...                            3
# 5             0          0           0   ...                            3
# 6             0          0           3   ...                            3
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 4                       7                       7          0           2
# 5                       7                       7          0           2
# 6                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 1            1          5                  1           2        0
# 2            1          5                  1           2        2
# 4            1          1                  1           0        0
# 5            1          5                  0           2        0
# 6            1          5                  0           2        2
#
# [5 rows x 23 columns]

# %%
import seaborn as sns
corr = poison.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

# %%
poison.corr()
# Out:
#                           class  cap-shape  cap-surface  cap-color   bruises  \
# class                       NaN        NaN          NaN        NaN       NaN
# cap-shape                   NaN   1.000000    -0.057503   0.019839  0.075801
# cap-surface                 NaN  -0.057503     1.000000  -0.214226 -0.304808
# cap-color                   NaN   0.019839    -0.214226   1.000000  0.050746
# bruises                     NaN   0.075801    -0.304808   0.050746  1.000000
# odor                        NaN  -0.122737     0.206997  -0.101796 -0.218908
# gill-attachment             NaN   0.004861    -0.001823   0.030041 -0.029585
# gill-spacing                NaN   0.126994    -0.070108   0.062061  0.041218
# gill-size                   NaN   0.027967     0.446504  -0.253386  0.127308
# gill-color                  NaN   0.011510    -0.284855   0.180928 -0.335328
# stalk-shape                 NaN  -0.056625     0.579623  -0.285542  0.046407
# stalk-root                  NaN   0.042393    -0.114327   0.100429 -0.644334
# stalk-surface-above-ring    NaN   0.011546     0.139709  -0.088295  0.005872
# stalk-surface-below-ring    NaN   0.019925     0.145975  -0.079570 -0.005344
# stalk-color-above-ring      NaN  -0.016421     0.510799  -0.216792 -0.369629
# stalk-color-below-ring      NaN  -0.010009     0.515666  -0.215037 -0.370991
# veil-type                   NaN        NaN          NaN        NaN       NaN
# veil-color                  NaN  -0.060944     0.001214   0.058325  0.019698
# ring-number                 NaN  -0.183962     0.053480   0.028812 -0.278823
# ring-type                   NaN   0.083433    -0.155973   0.153712 -0.693086
# spore-print-color           NaN  -0.144598     0.346841  -0.221134  0.446977
# population                  NaN  -0.006382    -0.308685   0.119130  0.358355
# habitat                     NaN   0.086550    -0.058179  -0.005085  0.244724
#
#                               odor  gill-attachment  gill-spacing  gill-size  \
# class                          NaN              NaN           NaN        NaN
# cap-shape                -0.122737         0.004861      0.126994   0.027967
# cap-surface               0.206997        -0.001823     -0.070108   0.446504
# cap-color                -0.101796         0.030041      0.062061  -0.253386
# bruises                  -0.218908        -0.029585      0.041218   0.127308
# odor                      1.000000        -0.015195     -0.200442   0.251640
# gill-attachment          -0.015195         1.000000      0.011660   0.077908
# gill-spacing             -0.200442         0.011660      1.000000   0.149665
# gill-size                 0.251640         0.077908      0.149665   1.000000
# gill-color               -0.113673        -0.085547      0.011199  -0.641834
# stalk-shape               0.146006         0.069998     -0.176749   0.601404
# stalk-root                0.167944        -0.084812      0.054055  -0.230819
# stalk-surface-above-ring  0.140104         0.032399      0.139640   0.471740
# stalk-surface-below-ring  0.123344         0.128902      0.139750   0.462397
# stalk-color-above-ring    0.186846         0.077107      0.150540   0.621580
# stalk-color-below-ring    0.177721         0.075859      0.151039   0.608386
# veil-type                      NaN              NaN           NaN        NaN
# veil-color                0.036046         0.003075      0.263681   0.039464
# ring-number               0.075942         0.413586     -0.009513  -0.063563
# ring-type                -0.127241        -0.064506      0.241650  -0.517868
# spore-print-color         0.174911        -0.069038     -0.227552   0.533715
# population               -0.112264         0.335101     -0.248071  -0.287128
# habitat                  -0.113696        -0.083981      0.158678   0.134441
#
#                           gill-color    ...     stalk-surface-below-ring  \
# class                            NaN    ...                          NaN
# cap-shape                   0.011510    ...                     0.019925
# cap-surface                -0.284855    ...                     0.145975
# cap-color                   0.180928    ...                    -0.079570
# bruises                    -0.335328    ...                    -0.005344
# odor                       -0.113673    ...                     0.123344
# gill-attachment            -0.085547    ...                     0.128902
# gill-spacing                0.011199    ...                     0.139750
# gill-size                  -0.641834    ...                     0.462397
# gill-color                  1.000000    ...                    -0.305876
# stalk-shape                -0.552614    ...                     0.087010
# stalk-root                  0.463749    ...                     0.065828
# stalk-surface-above-ring   -0.284240    ...                     0.375473
# stalk-surface-below-ring   -0.305876    ...                     1.000000
# stalk-color-above-ring     -0.313235    ...                     0.268606
# stalk-color-below-ring     -0.321645    ...                     0.284850
# veil-type                        NaN    ...                          NaN
# veil-color                  0.056958    ...                    -0.085824
# ring-number                -0.037400    ...                     0.218601
# ring-type                   0.603362    ...                    -0.085523
# spore-print-color          -0.585726    ...                     0.043950
# population                  0.008852    ...                    -0.049188
# habitat                    -0.091830    ...                     0.034692
#
#                           stalk-color-above-ring  stalk-color-below-ring  \
# class                                        NaN                     NaN
# cap-shape                              -0.016421               -0.010009
# cap-surface                             0.510799                0.515666
# cap-color                              -0.216792               -0.215037
# bruises                                -0.369629               -0.370991
# odor                                    0.186846                0.177721
# gill-attachment                         0.077107                0.075859
# gill-spacing                            0.150540                0.151039
# gill-size                               0.621580                0.608386
# gill-color                             -0.313235               -0.321645
# stalk-shape                             0.524238                0.530151
# stalk-root                             -0.048117               -0.040397
# stalk-surface-above-ring                0.271758                0.274271
# stalk-surface-below-ring                0.268606                0.284850
# stalk-color-above-ring                  1.000000                0.673975
# stalk-color-below-ring                  0.673975                1.000000
# veil-type                                    NaN                     NaN
# veil-color                              0.056363                0.056366
# ring-number                             0.157048                0.156376
# ring-type                              -0.048013               -0.038198
# spore-print-color                       0.241378                0.229718
# population                             -0.405168               -0.401558
# habitat                                 0.010104               -0.001901
#
#                           veil-type  veil-color  ring-number  ring-type  \
# class                           NaN         NaN          NaN        NaN
# cap-shape                       NaN   -0.060944    -0.183962   0.083433
# cap-surface                     NaN    0.001214     0.053480  -0.155973
# cap-color                       NaN    0.058325     0.028812   0.153712
# bruises                         NaN    0.019698    -0.278823  -0.693086
# odor                            NaN    0.036046     0.075942  -0.127241
# gill-attachment                 NaN    0.003075     0.413586  -0.064506
# gill-spacing                    NaN    0.263681    -0.009513   0.241650
# gill-size                       NaN    0.039464    -0.063563  -0.517868
# gill-color                      NaN    0.056958    -0.037400   0.603362
# stalk-shape                     NaN   -0.046605    -0.057109  -0.629938
# stalk-root                      NaN    0.056469    -0.042223   0.762501
# stalk-surface-above-ring        NaN   -0.089695     0.140521  -0.087105
# stalk-surface-below-ring        NaN   -0.085824     0.218601  -0.085523
# stalk-color-above-ring          NaN    0.056363     0.157048  -0.048013
# stalk-color-below-ring          NaN    0.056366     0.156376  -0.038198
# veil-type                       NaN         NaN          NaN        NaN
# veil-color                      NaN    1.000000    -0.002508  -0.044285
# ring-number                     NaN   -0.002508     1.000000   0.123891
# ring-type                       NaN   -0.044285     0.123891   1.000000
# spore-print-color               NaN    0.045966    -0.083512  -0.902019
# population                      NaN   -0.223115     0.267688  -0.209517
# habitat                         NaN   -0.042611    -0.172947  -0.082672
#
#                           spore-print-color  population   habitat
# class                                   NaN         NaN       NaN
# cap-shape                         -0.144598   -0.006382  0.086550
# cap-surface                        0.346841   -0.308685 -0.058179
# cap-color                         -0.221134    0.119130 -0.005085
# bruises                            0.446977    0.358355  0.244724
# odor                               0.174911   -0.112264 -0.113696
# gill-attachment                   -0.069038    0.335101 -0.083981
# gill-spacing                      -0.227552   -0.248071  0.158678
# gill-size                          0.533715   -0.287128  0.134441
# gill-color                        -0.585726    0.008852 -0.091830
# stalk-shape                        0.799059   -0.172735 -0.008772
# stalk-root                        -0.785596   -0.202836 -0.133438
# stalk-surface-above-ring           0.071889   -0.119620  0.068090
# stalk-surface-below-ring           0.043950   -0.049188  0.034692
# stalk-color-above-ring             0.241378   -0.405168  0.010104
# stalk-color-below-ring             0.229718   -0.401558 -0.001901
# veil-type                               NaN         NaN       NaN
# veil-color                         0.045966   -0.223115 -0.042611
# ring-number                       -0.083512    0.267688 -0.172947
# ring-type                         -0.902019   -0.209517 -0.082672
# spore-print-color                  1.000000   -0.045456  0.048673
# population                        -0.045456    1.000000 -0.047784
# habitat                            0.048673   -0.047784  1.000000
#
# [23 rows x 23 columns]

# %%
corr = edible.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

# %%
plt.scatter(edible['cap-color'],edible['habitat'])

# %%
from sklearn.linear_model import LogisticRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-137-d98c89d6b4be> in <module>
# ----> 1 from sklearn.linear_model import LogisticRegression
#
# ModuleNotFoundError: No module named 'sklearn'
